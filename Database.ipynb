# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Database exploration:

# %%
df = pd.read_csv(r'imdb_movies.csv')
df.head()
# Out:
#                          names       date_x  score  \
# 0                    Creed III  03/02/2023    73.0
# 1     Avatar: The Way of Water  12/15/2022    78.0
# 2  The Super Mario Bros. Movie  04/05/2023    76.0
# 3                      Mummies  01/05/2023    70.0
# 4                    Supercell  03/17/2023    61.0
#
#                                            genre  \
# 0                                  Drama, Action
# 1             Science Fiction, Adventure, Action
# 2  Animation, Adventure, Family, Fantasy, Comedy
# 3  Animation, Comedy, Family, Adventure, Fantasy
# 4                                         Action
#
#                                             overview  \
# 0  After dominating the boxing world, Adonis Cree...
# 1  Set more than a decade after the events of the...
# 2  While working underground to fix a water main,...
# 3  Through a series of unfortunate events, three ...
# 4  Good-hearted teenager William always lived in ...
#
#                                                 crew  \
# 0  Michael B. Jordan, Adonis Creed, Tessa Thompso...
# 1  Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 2  Chris Pratt, Mario (voice), Anya Taylor-Joy, P...
# 3  Óscar Barberán, Thut (voice), Ana Esther Albor...
# 4  Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
#
#                     orig_title     status            orig_lang     budget_x  \
# 0                    Creed III   Released              English   75000000.0
# 1     Avatar: The Way of Water   Released              English  460000000.0
# 2  The Super Mario Bros. Movie   Released              English  100000000.0
# 3                       Momias   Released   Spanish, Castilian   12300000.0
# 4                    Supercell   Released              English   77000000.0
#
#         revenue country
# 0  2.716167e+08      AU
# 1  2.316795e+09      AU
# 2  7.244590e+08      AU
# 3  3.420000e+07      AU
# 4  3.409420e+08      US

# %% [markdown]
# There's no ID value, so I'll add the index as a column.

# %%
df['ID']= df.index

# %% [markdown]
# I also noted this particular movie doesn't have a genre, so I will add it manually.

# %%
df[df['names']=="Moses, Prince of Egypt"]["genre"] 

df.loc[df['ID'] == 2020, 'genre'] = "Animation"

# %% [markdown]
# Now I'll drop every movie without a genre.

# %%
df = df.dropna(subset=['genre'])

# %% [markdown]
# Duplicates

# %%
df = df.drop_duplicates()

# %% [markdown]
# Movies with the same overview, which have to be the same:

# %%
df = df.drop_duplicates(subset=['overview'], keep='first')

# %%
df[df["names"].isin(df["names"][df["names"].duplicated()])].sort_values(by='names')
# Out:
#                           names       date_x  score  \
# 2072               12 Angry Men  10/10/1957    85.0
# 9741               12 Angry Men  08/17/1997    77.0
# 3028          A Christmas Carol  11/05/2009    69.0
# 7213          A Christmas Carol  10/09/1984    74.0
# 2373  A Nightmare on Elm Street  08/01/1985    73.0
# ...                         ...          ...    ...
# 924                  Wrong Turn  07/31/2003    63.0
# 8858          Wuthering Heights  10/16/1992    67.0
# 9749          Wuthering Heights  10/11/2012    59.0
# 4326                          X  11/23/2011    65.0
# 369                           X  03/24/2022    68.0
#
#                                   genre  \
# 2072                              Drama
# 9741             Crime, Drama, TV Movie
# 3028  Animation, Family, Drama, Fantasy
# 7213   Drama, Fantasy, TV Movie, Family
# 2373                             Horror
# ...                                 ...
# 924                    Horror, Thriller
# 8858                     Drama, Romance
# 9749                     Drama, Romance
# 4326          Action, Thriller, Romance
# 369           Horror, Mystery, Thriller
#
#                                                overview  \
# 2072  The defense and the prosecution have rested an...
# 9741  During the trial of a man accused of his fathe...
# 3028  Miser Ebenezer Scrooge is awakened on Christma...
# 7213  A bitter old miser who makes excuses for his u...
# 2373  Teenagers in a small town are dropping like fl...
# ...                                                 ...
# 924   Chris crashes into a carload of other young pe...
# 8858  Young orphan Heathcliff is adopted by the weal...
# 9749  Yorkshire moorlands, northern England, in the ...
# 4326  A veteran call girl and a runaway prostitute w...
# 369   In 1979, a group of young filmmakers set out t...
#
#                                                    crew  \
# 2072  Martin Balsam, Juror 1, John Fiedler, Juror 2,...
# 9741  Courtney B. Vance, Foreman, Ossie Davis, Juror...
# 3028  Jim Carrey, Scrooge / Ghosts of Christmas (voi...
# 7213  George C. Scott, Ebenezer Scrooge, Roger Rees,...
# 2373  John Saxon, Lieutenant Donald Thompson, Ronee ...
# ...                                                 ...
# 924   Eliza Dushku, Jessie Burlingame, Emmanuelle Ch...
# 8858  Juliette Binoche, Catherine Linton, Ralph Fien...
# 9749  Kaya Scodelario, Older Cathy, James Howson, Ol...
# 4326  Viva Bianca, Holly Rowe, Hanna Mangan Lawrence...
# 369   Mia Goth, Maxine Minx / Pearl, Jenna Ortega, L...
#
#                      orig_title     status orig_lang     budget_x  \
# 2072               12 Angry Men   Released   English     340000.0
# 9741               12 Angry Men   Released   English     340000.0
# 3028          A Christmas Carol   Released   English  200000000.0
# 7213          A Christmas Carol   Released   English  104200000.0
# 2373  A Nightmare on Elm Street   Released   English   35000000.0
# ...                         ...        ...       ...          ...
# 924                  Wrong Turn   Released   English   10000000.0
# 8858          Wuthering Heights   Released   English    8000000.0
# 9749          Wuthering Heights   Released   English    8000000.0
# 4326                          X   Released   English    1000000.0
# 369                           X   Released   English    1000000.0
#
#           revenue country
# 2072        379.0      AU
# 9741        379.0      US
# 3028  325286646.0      AU
# 7213  379238515.8      GB
# 2373  117729618.0      AU
# ...           ...     ...
# 924    28649556.0      AU
# 8858    2721534.0      US
# 9749    2721534.0      AU
# 4326   15113105.0      AU
# 369    15113105.0      AU
#
# [623 rows x 12 columns]

# %% [markdown]
# There are still movies with the same name, but they can correspond to different movies.

# %% [markdown]
# Now I can change the dates to datetime format:

# %%
df['date_x'] = pd.to_datetime(df['date_x'].str.strip(), format='%m/%d/%Y', errors='coerce')

# %%
df
# Out:
#                                          names     date_x  score  \
# 0                                    Creed III 2023-03-02   73.0
# 1                     Avatar: The Way of Water 2022-12-15   78.0
# 2                  The Super Mario Bros. Movie 2023-04-05   76.0
# 3                                      Mummies 2023-01-05   70.0
# 4                                    Supercell 2023-03-17   61.0
# ...                                        ...        ...    ...
# 10173                       20th Century Women 2016-12-28   73.0
# 10174  Delta Force 2: The Colombian Connection 1990-08-24   54.0
# 10175                         The Russia House 1990-12-21   61.0
# 10176         Darkman II: The Return of Durant 1995-07-11   55.0
# 10177       The Swan Princess: A Royal Wedding 2020-07-20   70.0
#
#                                                    genre  \
# 0                                          Drama, Action
# 1                     Science Fiction, Adventure, Action
# 2          Animation, Adventure, Family, Fantasy, Comedy
# 3          Animation, Comedy, Family, Adventure, Fantasy
# 4                                                 Action
# ...                                                  ...
# 10173                                              Drama
# 10174                                             Action
# 10175                           Drama, Thriller, Romance
# 10176  Action, Adventure, Science Fiction, Thriller, ...
# 10177                         Animation, Family, Fantasy
#
#                                                 overview  \
# 0      After dominating the boxing world, Adonis Cree...
# 1      Set more than a decade after the events of the...
# 2      While working underground to fix a water main,...
# 3      Through a series of unfortunate events, three ...
# 4      Good-hearted teenager William always lived in ...
# ...                                                  ...
# 10173  In 1979 Santa Barbara, California, Dorothea Fi...
# 10174  When DEA agents are taken captive by a ruthles...
# 10175  Barley Scott Blair, a Lisbon-based editor of R...
# 10176  Darkman and Durant return and they hate each o...
# 10177  Princess Odette and Prince Derek are going to ...
#
#                                                     crew  \
# 0      Michael B. Jordan, Adonis Creed, Tessa Thompso...
# 1      Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 2      Chris Pratt, Mario (voice), Anya Taylor-Joy, P...
# 3      Óscar Barberán, Thut (voice), Ana Esther Albor...
# 4      Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
# ...                                                  ...
# 10173  Annette Bening, Dorothea Fields, Lucas Jade Zu...
# 10174  Chuck Norris, Col. Scott McCoy, Billy Drago, R...
# 10175  Sean Connery, Bartholomew 'Barley' Scott Blair...
# 10176  Larry Drake, Robert G. Durant, Arnold Vosloo, ...
# 10177  Nina Herzog, Princess Odette (voice), Yuri Low...
#
#                                     orig_title     status  \
# 0                                    Creed III   Released
# 1                     Avatar: The Way of Water   Released
# 2                  The Super Mario Bros. Movie   Released
# 3                                       Momias   Released
# 4                                    Supercell   Released
# ...                                        ...        ...
# 10173                       20th Century Women   Released
# 10174  Delta Force 2: The Colombian Connection   Released
# 10175                         The Russia House   Released
# 10176         Darkman II: The Return of Durant   Released
# 10177       The Swan Princess: A Royal Wedding   Released
#
#                  orig_lang     budget_x       revenue country
# 0                  English   75000000.0  2.716167e+08      AU
# 1                  English  460000000.0  2.316795e+09      AU
# 2                  English  100000000.0  7.244590e+08      AU
# 3       Spanish, Castilian   12300000.0  3.420000e+07      AU
# 4                  English   77000000.0  3.409420e+08      US
# ...                    ...          ...           ...     ...
# 10173              English    7000000.0  9.353729e+06      US
# 10174              English    9145817.8  6.698361e+06      US
# 10175              English   21800000.0  2.299799e+07      US
# 10176              English  116000000.0  4.756613e+08      US
# 10177              English   92400000.0  5.394018e+08      GB
#
# [9847 rows x 12 columns]

# %%
pd.read_xml(r"C:\Users\julie\Downloads\sample_book.xml")
# Out:
#   authentication               key     method        id  \
# 0           true  all_men_must_die  book_show       NaN
# 1           None              None       None  205330.0
#
#                                        title         isbn        isbn13  asin  \
# 0                                       None          NaN           NaN   NaN
# 1  There Was an Old Lady Who Swallowed a Fly  670869392.0  9.780671e+12   NaN
#
#    kindle_asin  marketplace_id  ... text_reviews_count  \
# 0          NaN             NaN  ...                NaN
# 1          NaN             NaN  ...              716.0
#
#                                                  url  \
# 0                                               None
# 1  https://www.goodreads.com/book/show/205330.The...
#
#                                                 link  authors  \
# 0                                               None      NaN
# 1  https://www.goodreads.com/book/show/205330.The...      NaN
#
#                                       reviews_widget  popular_shelves  \
# 0                                               None              NaN
# 1  <style>\n  #goodreads-widget {\n    font-famil...              NaN
#
#    book_links  buy_links series_works  similar_books
# 0         NaN        NaN          NaN            NaN
# 1         NaN        NaN          NaN            NaN
#
# [2 rows x 36 columns]
